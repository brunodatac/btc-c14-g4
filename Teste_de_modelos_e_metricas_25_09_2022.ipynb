# %% [markdown]
# <a href="https://colab.research.google.com/github/flaviowu/btc-c14-g4/blob/main/Teste_de_modelos_e_metricas_25_09_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Para este projeto, os dados utilizados foram obtidos do Kaggle - https://www.kaggle.com/competitions/mercari-price-suggestion-challenge/overview
#
# Thiago Junior Charles 25/09/2022

# %% [markdown]
# ### Importação de Bibliotecas

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import random
import seaborn as sns



from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel 
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Leitura do arquivo

# %%
train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/modulo 6/train.tsv', sep = '\t')
test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/modulo 6/test.tsv', sep = '\t')

# %%
display(train.head())
display(train.tail())
# Out:
#    train_id                                 name  item_condition_id  \
# 0         0  MLB Cincinnati Reds T Shirt Size XL                  3
# 1         1     Razer BlackWidow Chroma Keyboard                  3
# 2         2                       AVA-VIV Blouse                  1
# 3         3                Leather Horse Statues                  1
# 4         4                 24K GOLD plated rose                  1
#
#                                        category_name brand_name  price  \
# 0                                  Men/Tops/T-shirts        NaN   10.0
# 1  Electronics/Computers & Tablets/Components & P...      Razer   52.0
# 2                        Women/Tops & Blouses/Blouse     Target   10.0
# 3                 Home/Home Décor/Home Décor Accents        NaN   35.0
# 4                            Women/Jewelry/Necklaces        NaN   44.0
#
#    shipping                                   item_description
# 0         1                                 No description yet
# 1         0  This keyboard is in great condition and works ...
# 2         1  Adorable top with a hint of lace and a key hol...
# 3         1  New with tags. Leather horses. Retail for [rm]...
# 4         0          Complete with certificate of authenticity
#          train_id                                   name  item_condition_id  \
# 1482530   1482530             Free People Inspired Dress                  2
# 1482531   1482531          Little mermaid handmade dress                  2
# 1482532   1482532  21 day fix containers and eating plan                  2
# 1482533   1482533                 World markets lanterns                  3
# 1482534   1482534          Brand new lux de ville wallet                  1
#
#                                           category_name   brand_name  price  \
# 1482530                          Women/Dresses/Mid-Calf  Free People   20.0
# 1482531                        Kids/Girls 2T-5T/Dresses       Disney   14.0
# 1482532  Sports & Outdoors/Exercise/Fitness accessories          NaN   12.0
# 1482533              Home/Home Décor/Home Décor Accents          NaN   45.0
# 1482534               Women/Women's Accessories/Wallets          NaN   22.0
#
#          shipping                                   item_description
# 1482530         1  Lace, says size small but fits medium perfectl...
# 1482531         0   Little mermaid handmade dress never worn size 2t
# 1482532         0          Used once or twice, still in great shape.
# 1482533         1  There is 2 of each one that you see! So 2 red ...
# 1482534         0  New with tag, red with sparkle. Firm price, no...

# %%
display(test.head())
display(test.tail())
# Out:
#    test_id                                      name  item_condition_id  \
# 0        0  Breast cancer "I fight like a girl" ring                  1
# 1        1  25 pcs NEW 7.5"x12" Kraft Bubble Mailers                  1
# 2        2                                 Coach bag                  1
# 3        3                             Floral Kimono                  2
# 4        4                          Life after Death                  3
#
#                                     category_name brand_name  shipping  \
# 0                             Women/Jewelry/Rings        NaN         1
# 1         Other/Office supplies/Shipping Supplies        NaN         1
# 2  Vintage & Collectibles/Bags and Purses/Handbag      Coach         1
# 3                         Women/Sweaters/Cardigan        NaN         0
# 4             Other/Books/Religion & Spirituality        NaN         1
#
#                                     item_description
# 0                                             Size 7
# 1  25 pcs NEW 7.5"x12" Kraft Bubble Mailers Lined...
# 2  Brand new coach bag. Bought for [rm] at a Coac...
# 3  -floral kimono -never worn -lightweight and pe...
# 4  Rediscovering life after the loss of a loved o...
#         test_id                                   name  item_condition_id  \
# 693354   693354          Quartz crystal on Flint stone                  1
# 693355   693355           It Cosmetics - Travel Bundle                  1
# 693356   693356              Galaxy S8 hard shell case                  1
# 693357   693357                   Hi low floral kimono                  2
# 693358   693358  FREESHIP 2 Floral Scrub Tops, medium.                  2
#
#                                             category_name    brand_name  \
# 693354                 Home/Home Décor/Home Décor Accents           NaN
# 693355                          Beauty/Makeup/Makeup Sets  IT Cosmetics
# 693356  Electronics/Cell Phones & Accessories/Cases, C...           NaN
# 693357                           Women/Swimwear/Cover-Ups           NaN
# 693358                      Women/Tops & Blouses/T-Shirts           NaN
#
#         shipping                                   item_description
# 693354         0  Flint/Quartz cluster. Self mined ✨measures 3x2...
# 693355         1  It Cosmetics travel bundle. Includes: Brow pow...
# 693356         1                    New. Free shipping Basstop case
# 693357         0  Floral kimono. Tropical print. Open front. Hi ...
# 693358         1  2 Floral scrub tops. Worn less than 5 times ea...

# %% [markdown]
# ### Indexes redundantes

# %%
print(train.describe())
print('------------------------------------------\n')
print(train.info())
# Out:
#            train_id  item_condition_id         price      shipping
# count  1.482535e+06       1.482535e+06  1.482535e+06  1.482535e+06
# mean   7.412670e+05       1.907380e+00  2.673752e+01  4.472744e-01
# std    4.279711e+05       9.031586e-01  3.858607e+01  4.972124e-01
# min    0.000000e+00       1.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.706335e+05       1.000000e+00  1.000000e+01  0.000000e+00
# 50%    7.412670e+05       2.000000e+00  1.700000e+01  0.000000e+00
# 75%    1.111900e+06       3.000000e+00  2.900000e+01  1.000000e+00
# max    1.482534e+06       5.000000e+00  2.009000e+03  1.000000e+00
# ------------------------------------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1482535 entries, 0 to 1482534
# Data columns (total 8 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   train_id           1482535 non-null  int64
#  1   name               1482535 non-null  object
#  2   item_condition_id  1482535 non-null  int64
#  3   category_name      1476208 non-null  object
#  4   brand_name         849853 non-null   object
#  5   price              1482535 non-null  float64
#  6   shipping           1482535 non-null  int64
#  7   item_description   1482531 non-null  object
# dtypes: float64(1), int64(3), object(4)
# memory usage: 90.5+ MB
# None

# %%
print(test.describe())
print('------------------------------------------\n')
print(test.info())
# Out:
#              test_id  item_condition_id       shipping
# count  693359.000000      693359.000000  693359.000000
# mean   346679.000000           1.906102       0.447719
# std    200155.646985           0.903378       0.497260
# min         0.000000           1.000000       0.000000
# 25%    173339.500000           1.000000       0.000000
# 50%    346679.000000           2.000000       0.000000
# 75%    520018.500000           3.000000       1.000000
# max    693358.000000           5.000000       1.000000
# ------------------------------------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693359 entries, 0 to 693358
# Data columns (total 7 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   test_id            693359 non-null  int64
#  1   name               693359 non-null  object
#  2   item_condition_id  693359 non-null  int64
#  3   category_name      690301 non-null  object
#  4   brand_name         397834 non-null  object
#  5   shipping           693359 non-null  int64
#  6   item_description   693359 non-null  object
# dtypes: int64(3), object(4)
# memory usage: 37.0+ MB
# None

# %% [markdown]
# ### Valores Nulos

# %%
train.isna().value_counts()
# Out:
# train_id  name   item_condition_id  category_name  brand_name  price  shipping  item_description
# False     False  False              False          False       False  False     False               846982
#                                                    True        False  False     False               629222
#                                     True           True        False  False     False                 3457
#                                                    False       False  False     False                 2870
#                                     False          True        False  False     True                     3
#                                                    False       False  False     True                     1
# dtype: int64

# %%
test.isna().value_counts()
# Out:
# test_id  name   item_condition_id  category_name  brand_name  shipping  item_description
# False    False  False              False          False       False     False               396431
#                                                   True        False     False               293870
#                                    True           True        False     False                 1655
#                                                   False       False     False                 1403
# dtype: int64

# %% [markdown]
# 6327 valores nulos em ```category_name```

# %%
train.loc[ train.category_name.isna() == True ]['category_name'].shape
# Out:
# (6327,)

# %%
test.loc[ test.category_name.isna() == True ]['category_name'].shape
# Out:
# (3058,)

# %% [markdown]
# 632682 valores nulos na coluna ```brand_name```.
#
# Representam 42.68% das observações.

# %%
train.loc[ train.brand_name.isna() == True ]['brand_name'].shape
# Out:
# (632682,)

# %%
test.loc[ test.brand_name.isna() == True ]['brand_name'].shape
# Out:
# (295525,)

# %%
print(f"Proporção de nulos no train: {round(train.loc[ train.brand_name.isna() == True ]['brand_name'].shape[0]/train.shape[0]*100, 2)}%")
# Out:
# Proporção de nulos no train: 42.68%

# %%
print(f"Proporção de nulos no test: {round(test.loc[ test.brand_name.isna() == True ]['brand_name'].shape[0]/test.shape[0]*100, 2)}%")
# Out:
# Proporção de nulos no test: 42.62%

# %%
train.loc[ train.item_description.isna() == True ]
# Out:
#          train_id                     name  item_condition_id  \
# 511535     511535       Shoes for Michelle                  4
# 861230     861230                 Lipgloss                  4
# 1224924   1224924  Disney Minnie Head band                  3
# 1264242   1264242               For Bianca                  3
#
#                                       category_name brand_name  price  \
# 511535                    Kids/Girls 0-24 Mos/Shoes        NaN    9.0
# 861230                           Beauty/Makeup/Lips        NaN   49.0
# 1224924  Women/Women's Accessories/Hair Accessories     Disney    9.0
# 1264242   Women/Women's Accessories/Scarves & Wraps        NaN   10.0
#
#          shipping item_description
# 511535          0              NaN
# 861230          0              NaN
# 1224924         0              NaN
# 1264242         1              NaN

# %%
test.loc[ test.item_description.isna() == True ]
# Out:
# Empty DataFrame
# Columns: [test_id, name, item_condition_id, category_name, brand_name, shipping, item_description]
# Index: []

# %% [markdown]
# ## Separando as categorias

# %%
categories = train.category_name.str.split('/', expand=True)
categories.head()
# Out:
#              0                    1                   2     3     4
# 0          Men                 Tops            T-shirts  None  None
# 1  Electronics  Computers & Tablets  Components & Parts  None  None
# 2        Women       Tops & Blouses              Blouse  None  None
# 3         Home           Home Décor  Home Décor Accents  None  None
# 4        Women              Jewelry           Necklaces  None  None

# %%
categories_test = test.category_name.str.split('/', expand=True)
categories_test.head()
# Out:
#                         0                1                        2     3  \
# 0                   Women          Jewelry                    Rings  None
# 1                   Other  Office supplies        Shipping Supplies  None
# 2  Vintage & Collectibles  Bags and Purses                  Handbag  None
# 3                   Women         Sweaters                 Cardigan  None
# 4                   Other            Books  Religion & Spirituality  None
#
#       4
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
categories.columns = ['main_cat', 'sub_cat_1', 'sub_cat_2', 'sub_cat_3', 'sub_cat_4']
categories.head()
# Out:
#       main_cat            sub_cat_1           sub_cat_2 sub_cat_3 sub_cat_4
# 0          Men                 Tops            T-shirts      None      None
# 1  Electronics  Computers & Tablets  Components & Parts      None      None
# 2        Women       Tops & Blouses              Blouse      None      None
# 3         Home           Home Décor  Home Décor Accents      None      None
# 4        Women              Jewelry           Necklaces      None      None

# %%
categories_test.columns = ['main_cat', 'sub_cat_1', 'sub_cat_2', 'sub_cat_3', 'sub_cat_4']
categories_test.head()
# Out:
#                  main_cat        sub_cat_1                sub_cat_2 sub_cat_3  \
# 0                   Women          Jewelry                    Rings      None
# 1                   Other  Office supplies        Shipping Supplies      None
# 2  Vintage & Collectibles  Bags and Purses                  Handbag      None
# 3                   Women         Sweaters                 Cardigan      None
# 4                   Other            Books  Religion & Spirituality      None
#
#   sub_cat_4
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None

# %%
train = pd.concat([train, categories], axis=1)
test = pd.concat([test, categories_test], axis=1)

# %%
train.head(0)
# Out:
# Empty DataFrame
# Columns: [train_id, name, item_condition_id, category_name, brand_name, price, shipping, item_description, main_cat, sub_cat_1, sub_cat_2, sub_cat_3, sub_cat_4]
# Index: []

# %%
test.head(0)
# Out:
# Empty DataFrame
# Columns: [test_id, name, item_condition_id, category_name, brand_name, shipping, item_description, main_cat, sub_cat_1, sub_cat_2, sub_cat_3, sub_cat_4]
# Index: []

# %%
train.shape
# Out:
# (1482535, 13)

# %%
test.shape
# Out:
# (693359, 12)

# %%
train.drop('category_name', axis=1, inplace=True)
train.columns
# Out:
# Index(['train_id', 'name', 'item_condition_id', 'brand_name', 'price',
#        'shipping', 'item_description', 'main_cat', 'sub_cat_1', 'sub_cat_2',
#        'sub_cat_3', 'sub_cat_4'],
#       dtype='object')

# %%
test.drop('category_name', axis=1, inplace=True)
test.columns
# Out:
# Index(['test_id', 'name', 'item_condition_id', 'brand_name', 'shipping',
#        'item_description', 'main_cat', 'sub_cat_1', 'sub_cat_2', 'sub_cat_3',
#        'sub_cat_4'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1482535 entries, 0 to 1482534
# Data columns (total 12 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   train_id           1482535 non-null  int64
#  1   name               1482535 non-null  object
#  2   item_condition_id  1482535 non-null  int64
#  3   brand_name         849853 non-null   object
#  4   price              1482535 non-null  float64
#  5   shipping           1482535 non-null  int64
#  6   item_description   1482531 non-null  object
#  7   main_cat           1476208 non-null  object
#  8   sub_cat_1          1476208 non-null  object
#  9   sub_cat_2          1476208 non-null  object
#  10  sub_cat_3          4389 non-null     object
#  11  sub_cat_4          3059 non-null     object
# dtypes: float64(1), int64(3), object(8)
# memory usage: 135.7+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693359 entries, 0 to 693358
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   test_id            693359 non-null  int64
#  1   name               693359 non-null  object
#  2   item_condition_id  693359 non-null  int64
#  3   brand_name         397834 non-null  object
#  4   shipping           693359 non-null  int64
#  5   item_description   693359 non-null  object
#  6   main_cat           690301 non-null  object
#  7   sub_cat_1          690301 non-null  object
#  8   sub_cat_2          690301 non-null  object
#  9   sub_cat_3          2046 non-null    object
#  10  sub_cat_4          1419 non-null    object
# dtypes: int64(3), object(8)
# memory usage: 58.2+ MB

# %%
train = train.drop(columns=['sub_cat_3',])
train = train.drop(columns=['sub_cat_4',])
test = test.drop(columns=['sub_cat_3',])
test = test.drop(columns=['sub_cat_4',])

train = train.rename(columns = {'train_id':'id'})
test = test.rename(columns = {'test_id':'id'})
drop_train = ['id','is_train']
drop_test = ['id','is_train']
value_vars = ['item_condition_id','shipping']
category_vars = ['name','main_cat','sub_cat_1','sub_cat_2','brand_name','item_description']


print(train.isna())
print(test.isna())
for v in value_vars:
    print(v)
    print(train[train[v].isna()])

for c in category_vars:
    print(c)
    print(train[train[c].isna()])

train = train.fillna('Blank') 
test = test.fillna('Blank')
# Out:
#             id   name  item_condition_id  brand_name  price  shipping  \
# 0        False  False              False        True  False     False
# 1        False  False              False       False  False     False
# 2        False  False              False       False  False     False
# 3        False  False              False        True  False     False
# 4        False  False              False        True  False     False
# ...        ...    ...                ...         ...    ...       ...
# 1482530  False  False              False       False  False     False
# 1482531  False  False              False       False  False     False
# 1482532  False  False              False        True  False     False
# 1482533  False  False              False        True  False     False
# 1482534  False  False              False        True  False     False
#
#          item_description  main_cat  sub_cat_1  sub_cat_2
# 0                   False     False      False      False
# 1                   False     False      False      False
# 2                   False     False      False      False
# 3                   False     False      False      False
# 4                   False     False      False      False
# ...                   ...       ...        ...        ...
# 1482530             False     False      False      False
# 1482531             False     False      False      False
# 1482532             False     False      False      False
# 1482533             False     False      False      False
# 1482534             False     False      False      False
#
# [1482535 rows x 10 columns]
#            id   name  item_condition_id  brand_name  shipping  \
# 0       False  False              False        True     False
# 1       False  False              False        True     False
# 2       False  False              False       False     False
# 3       False  False              False        True     False
# 4       False  False              False        True     False
# ...       ...    ...                ...         ...       ...
# 693354  False  False              False        True     False
# 693355  False  False              False       False     False
# 693356  False  False              False        True     False
# 693357  False  False              False        True     False
# 693358  False  False              False        True     False
#
#         item_description  main_cat  sub_cat_1  sub_cat_2
# 0                  False     False      False      False
# 1                  False     False      False      False
# 2                  False     False      False      False
# 3                  False     False      False      False
# 4                  False     False      False      False
# ...                  ...       ...        ...        ...
# 693354             False     False      False      False
# 693355             False     False      False      False
# 693356             False     False      False      False
# 693357             False     False      False      False
# 693358             False     False      False      False
#
# [693359 rows x 9 columns]
# item_condition_id
# Empty DataFrame
# Columns: [id, name, item_condition_id, brand_name, price, shipping, item_description, main_cat, sub_cat_1, sub_cat_2]
# Index: []
# shipping
# Empty DataFrame
# Columns: [id, name, item_condition_id, brand_name, price, shipping, item_description, main_cat, sub_cat_1, sub_cat_2]
# Index: []
# name
# Empty DataFrame
# Columns: [id, name, item_condition_id, brand_name, price, shipping, item_description, main_cat, sub_cat_1, sub_cat_2]
# Index: []
# main_cat
#               id                                      name  item_condition_id  \
# 122          122                                    Bundle                  3
# 155          155                      3 Nora Roberts Books                  3
# 258          258                               ACER Laptop                  5
# 984          984  AUTHENTIC BRWN MICHAEL KORS MAKEUP STAIN                  4
# 1185        1185   Teenage Mutant Ninja Turtle Van/ Extras                  3
# ...          ...                                       ...                ...
# 1481249  1481249                 Only For Erin. Do Not Buy                  3
# 1481750  1481750                   American Eagle Jeggings                  2
# 1482252  1482252                   Bundle For All Honey :)                  3
# 1482443  1482443   HOLD 14g Purple Prong Nipple Bars Rings                  1
# 1482473  1482473                         Puma Suede Emboss                  2
#
#              brand_name  price  shipping  \
# 122                 NaN   59.0         0
# 155                 NaN   10.0         1
# 258                 NaN   14.0         0
# 984        Michael Kors   18.0         0
# 1185        Nickelodeon    9.0         0
# ...                 ...    ...       ...
# 1481249             NaN   31.0         0
# 1481750  American Eagle   17.0         0
# 1482252             NaN   40.0         0
# 1482443             NaN   22.0         1
# 1482473            PUMA   30.0         1
#
#                                           item_description main_cat sub_cat_1  \
# 122      Sizes and info of clothes can be found on thei...      NaN       NaN
# 155                                           For aferg16.      NaN       NaN
# 258      Powers on, no screen display, no external dama...      NaN       NaN
# 984                                     No description yet      NaN       NaN
# 1185     Teenage Mutant Ninja Turtle Van, April O'Neil ...      NaN       NaN
# ...                                                    ...      ...       ...
# 1481249                                 No description yet      NaN       NaN
# 1481750                       Worn a couple of time Size 4      NaN       NaN
# 1482252                                 No description yet      NaN       NaN
# 1482443  14g Purple Prong Set Nipple Bars Rings [surgic...      NaN       NaN
# 1482473                    Worn Once!!! Great condition!!!      NaN       NaN
#
#         sub_cat_2
# 122           NaN
# 155           NaN
# 258           NaN
# 984           NaN
# 1185          NaN
# ...           ...
# 1481249       NaN
# 1481750       NaN
# 1482252       NaN
# 1482443       NaN
# 1482473       NaN
#
# [6327 rows x 10 columns]
# sub_cat_1
#               id                                      name  item_condition_id  \
# 122          122                                    Bundle                  3
# 155          155                      3 Nora Roberts Books                  3
# 258          258                               ACER Laptop                  5
# 984          984  AUTHENTIC BRWN MICHAEL KORS MAKEUP STAIN                  4
# 1185        1185   Teenage Mutant Ninja Turtle Van/ Extras                  3
# ...          ...                                       ...                ...
# 1481249  1481249                 Only For Erin. Do Not Buy                  3
# 1481750  1481750                   American Eagle Jeggings                  2
# 1482252  1482252                   Bundle For All Honey :)                  3
# 1482443  1482443   HOLD 14g Purple Prong Nipple Bars Rings                  1
# 1482473  1482473                         Puma Suede Emboss                  2
#
#              brand_name  price  shipping  \
# 122                 NaN   59.0         0
# 155                 NaN   10.0         1
# 258                 NaN   14.0         0
# 984        Michael Kors   18.0         0
# 1185        Nickelodeon    9.0         0
# ...                 ...    ...       ...
# 1481249             NaN   31.0         0
# 1481750  American Eagle   17.0         0
# 1482252             NaN   40.0         0
# 1482443             NaN   22.0         1
# 1482473            PUMA   30.0         1
#
#                                           item_description main_cat sub_cat_1  \
# 122      Sizes and info of clothes can be found on thei...      NaN       NaN
# 155                                           For aferg16.      NaN       NaN
# 258      Powers on, no screen display, no external dama...      NaN       NaN
# 984                                     No description yet      NaN       NaN
# 1185     Teenage Mutant Ninja Turtle Van, April O'Neil ...      NaN       NaN
# ...                                                    ...      ...       ...
# 1481249                                 No description yet      NaN       NaN
# 1481750                       Worn a couple of time Size 4      NaN       NaN
# 1482252                                 No description yet      NaN       NaN
# 1482443  14g Purple Prong Set Nipple Bars Rings [surgic...      NaN       NaN
# 1482473                    Worn Once!!! Great condition!!!      NaN       NaN
#
#         sub_cat_2
# 122           NaN
# 155           NaN
# 258           NaN
# 984           NaN
# 1185          NaN
# ...           ...
# 1481249       NaN
# 1481750       NaN
# 1482252       NaN
# 1482443       NaN
# 1482473       NaN
#
# [6327 rows x 10 columns]
# sub_cat_2
#               id                                      name  item_condition_id  \
# 122          122                                    Bundle                  3
# 155          155                      3 Nora Roberts Books                  3
# 258          258                               ACER Laptop                  5
# 984          984  AUTHENTIC BRWN MICHAEL KORS MAKEUP STAIN                  4
# 1185        1185   Teenage Mutant Ninja Turtle Van/ Extras                  3
# ...          ...                                       ...                ...
# 1481249  1481249                 Only For Erin. Do Not Buy                  3
# 1481750  1481750                   American Eagle Jeggings                  2
# 1482252  1482252                   Bundle For All Honey :)                  3
# 1482443  1482443   HOLD 14g Purple Prong Nipple Bars Rings                  1
# 1482473  1482473                         Puma Suede Emboss                  2
#
#              brand_name  price  shipping  \
# 122                 NaN   59.0         0
# 155                 NaN   10.0         1
# 258                 NaN   14.0         0
# 984        Michael Kors   18.0         0
# 1185        Nickelodeon    9.0         0
# ...                 ...    ...       ...
# 1481249             NaN   31.0         0
# 1481750  American Eagle   17.0         0
# 1482252             NaN   40.0         0
# 1482443             NaN   22.0         1
# 1482473            PUMA   30.0         1
#
#                                           item_description main_cat sub_cat_1  \
# 122      Sizes and info of clothes can be found on thei...      NaN       NaN
# 155                                           For aferg16.      NaN       NaN
# 258      Powers on, no screen display, no external dama...      NaN       NaN
# 984                                     No description yet      NaN       NaN
# 1185     Teenage Mutant Ninja Turtle Van, April O'Neil ...      NaN       NaN
# ...                                                    ...      ...       ...
# 1481249                                 No description yet      NaN       NaN
# 1481750                       Worn a couple of time Size 4      NaN       NaN
# 1482252                                 No description yet      NaN       NaN
# 1482443  14g Purple Prong Set Nipple Bars Rings [surgic...      NaN       NaN
# 1482473                    Worn Once!!! Great condition!!!      NaN       NaN
#
#         sub_cat_2
# 122           NaN
# 155           NaN
# 258           NaN
# 984           NaN
# 1185          NaN
# ...           ...
# 1481249       NaN
# 1481750       NaN
# 1482252       NaN
# 1482443       NaN
# 1482473       NaN
#
# [6327 rows x 10 columns]
# brand_name
#               id                                    name  item_condition_id  \
# 0              0     MLB Cincinnati Reds T Shirt Size XL                  3
# 3              3                   Leather Horse Statues                  1
# 4              4                    24K GOLD plated rose                  1
# 5              5        Bundled items requested for Ruie                  3
# 9              9  Porcelain clown doll checker pants VTG                  3
# ...          ...                                     ...                ...
# 1482526  1482526    Harry Potter Shirt! Women M/ Girl XL                  2
# 1482527  1482527   Blk/white ribbed mock neck bodysuit M                  1
# 1482532  1482532   21 day fix containers and eating plan                  2
# 1482533  1482533                  World markets lanterns                  3
# 1482534  1482534           Brand new lux de ville wallet                  1
#
#         brand_name  price  shipping  \
# 0              NaN   10.0         1
# 3              NaN   35.0         1
# 4              NaN   44.0         0
# 5              NaN   59.0         0
# 9              NaN    8.0         0
# ...            ...    ...       ...
# 1482526        NaN   12.0         0
# 1482527        NaN   10.0         1
# 1482532        NaN   12.0         0
# 1482533        NaN   45.0         1
# 1482534        NaN   22.0         0
#
#                                           item_description  \
# 0                                       No description yet
# 3        New with tags. Leather horses. Retail for [rm]...
# 4                Complete with certificate of authenticity
# 5        Banana republic bottoms, Candies skirt with ma...
# 9        I realized his pants are on backwards after th...
# ...                                                    ...
# 1482526  Great Harry Potter Shirt! "Hogwarts, School of...
# 1482527  Brand new black and white ribbed mock neck bod...
# 1482532          Used once or twice, still in great shape.
# 1482533  There is 2 of each one that you see! So 2 red ...
# 1482534  New with tag, red with sparkle. Firm price, no...
#
#                        main_cat            sub_cat_1            sub_cat_2
# 0                           Men                 Tops             T-shirts
# 3                          Home           Home Décor   Home Décor Accents
# 4                         Women              Jewelry            Necklaces
# 5                         Women                Other                Other
# 9        Vintage & Collectibles         Collectibles                 Doll
# ...                         ...                  ...                  ...
# 1482526                   Women       Tops & Blouses             T-Shirts
# 1482527                   Women       Tops & Blouses               Blouse
# 1482532       Sports & Outdoors             Exercise  Fitness accessories
# 1482533                    Home           Home Décor   Home Décor Accents
# 1482534                   Women  Women's Accessories              Wallets
#
# [632682 rows x 10 columns]
# item_description
#               id                     name  item_condition_id brand_name  \
# 511535    511535       Shoes for Michelle                  4        NaN
# 861230    861230                 Lipgloss                  4        NaN
# 1224924  1224924  Disney Minnie Head band                  3     Disney
# 1264242  1264242               For Bianca                  3        NaN
#
#          price  shipping item_description main_cat            sub_cat_1  \
# 511535     9.0         0              NaN     Kids       Girls 0-24 Mos
# 861230    49.0         0              NaN   Beauty               Makeup
# 1224924    9.0         0              NaN    Women  Women's Accessories
# 1264242   10.0         1              NaN    Women  Women's Accessories
#
#                 sub_cat_2
# 511535              Shoes
# 861230               Lips
# 1224924  Hair Accessories
# 1264242   Scarves & Wraps

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1482535 entries, 0 to 1482534
# Data columns (total 10 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   id                 1482535 non-null  int64
#  1   name               1482535 non-null  object
#  2   item_condition_id  1482535 non-null  int64
#  3   brand_name         1482535 non-null  object
#  4   price              1482535 non-null  float64
#  5   shipping           1482535 non-null  int64
#  6   item_description   1482535 non-null  object
#  7   main_cat           1482535 non-null  object
#  8   sub_cat_1          1482535 non-null  object
#  9   sub_cat_2          1482535 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 113.1+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693359 entries, 0 to 693358
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 693359 non-null  int64
#  1   name               693359 non-null  object
#  2   item_condition_id  693359 non-null  int64
#  3   brand_name         693359 non-null  object
#  4   shipping           693359 non-null  int64
#  5   item_description   693359 non-null  object
#  6   main_cat           693359 non-null  object
#  7   sub_cat_1          693359 non-null  object
#  8   sub_cat_2          693359 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 47.6+ MB

# %% [markdown]
# ## Conversão de texto para nº

# %%
# Combine teste e treine uma vez e altere o tipo de dados de uma só vez
# adiciona uma coluna para dividir em ambos os conjuntos
train['is_train'] = 1  # aki vai colocar a coluna is_train =1 no train, para diferenciar quando juntar os 2 df para transformar em texto e depois separar 
test['is_train'] = 0   # aki vai colocar a coluna is_train =1 no test, para diferenciar quando juntar os 2 df para transformar em texto e depois separar 

# define concatenação
combine = pd.concat([train.drop(['price'], axis=1),test],axis=0)
display(combine.head())
# Out:
#    id                                 name  item_condition_id brand_name  \
# 0   0  MLB Cincinnati Reds T Shirt Size XL                  3      Blank
# 1   1     Razer BlackWidow Chroma Keyboard                  3      Razer
# 2   2                       AVA-VIV Blouse                  1     Target
# 3   3                Leather Horse Statues                  1      Blank
# 4   4                 24K GOLD plated rose                  1      Blank
#
#    shipping                                   item_description     main_cat  \
# 0         1                                 No description yet          Men
# 1         0  This keyboard is in great condition and works ...  Electronics
# 2         1  Adorable top with a hint of lace and a key hol...        Women
# 3         1  New with tags. Leather horses. Retail for [rm]...         Home
# 4         0          Complete with certificate of authenticity        Women
#
#              sub_cat_1           sub_cat_2  is_train
# 0                 Tops            T-shirts         1
# 1  Computers & Tablets  Components & Parts         1
# 2       Tops & Blouses              Blouse         1
# 3           Home Décor  Home Décor Accents         1
# 4              Jewelry           Necklaces         1

# %%
# altera o tipo de dados de variáveis ​​categóricas e convertendo para nº
#name
combine.name = combine.name.astype('category')
#brand_name         
combine.brand_name = combine.brand_name.astype('category')
#item_description   
combine.item_description = combine.item_description.astype('category')
#main_cat           
combine.main_cat = combine.main_cat.astype('category')
#sub_cat_1          
combine.sub_cat_1 = combine.sub_cat_1.astype('category')
#sub_cat_2          
combine.sub_cat_2  = combine.sub_cat_2 .astype('category')

display(combine.head())
# Out:
#    id                                 name  item_condition_id brand_name  \
# 0   0  MLB Cincinnati Reds T Shirt Size XL                  3      Blank
# 1   1     Razer BlackWidow Chroma Keyboard                  3      Razer
# 2   2                       AVA-VIV Blouse                  1     Target
# 3   3                Leather Horse Statues                  1      Blank
# 4   4                 24K GOLD plated rose                  1      Blank
#
#    shipping                                   item_description     main_cat  \
# 0         1                                 No description yet          Men
# 1         0  This keyboard is in great condition and works ...  Electronics
# 2         1  Adorable top with a hint of lace and a key hol...        Women
# 3         1  New with tags. Leather horses. Retail for [rm]...         Home
# 4         0          Complete with certificate of authenticity        Women
#
#              sub_cat_1           sub_cat_2  is_train
# 0                 Tops            T-shirts         1
# 1  Computers & Tablets  Components & Parts         1
# 2       Tops & Blouses              Blouse         1
# 3           Home Décor  Home Décor Accents         1
# 4              Jewelry           Necklaces         1

# %%
# Codifique a string de combinação com ".cat.codes"
combine.name = combine.name.cat.codes
combine.brand_name = combine.brand_name.cat.codes
combine.item_description = combine.item_description.cat.codes
combine.main_cat = combine.main_cat.cat.codes
combine.sub_cat_1 = combine.sub_cat_1.cat.codes
combine.sub_cat_2 = combine.sub_cat_2.cat.codes

# %%
display(combine.info())
display(combine.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175894 entries, 0 to 693358
# Data columns (total 10 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   id                 int64
#  1   name               int32
#  2   item_condition_id  int64
#  3   brand_name         int16
#  4   shipping           int64
#  5   item_description   int32
#  6   main_cat           int8
#  7   sub_cat_1          int8
#  8   sub_cat_2          int16
#  9   is_train           int64
# dtypes: int16(2), int32(2), int64(4), int8(2)
# memory usage: 112.1 MB
# None
#    id     name  item_condition_id  brand_name  shipping  item_description  \
# 0   0   916335                  3         646         1           1172054
# 1   1  1292428                  3        3889         0           1585540
# 2   2   131013                  1        4588         1            167133
# 3   3   802671                  1         646         1           1136644
# 4   4    65051                  1         646         0            531910
#
#    main_cat  sub_cat_1  sub_cat_2  is_train
# 0         6        103        774         1
# 1         2         31        216         1
# 2        10        104         98         1
# 3         4         56        411         1
# 4        10         59        543         1

# %%
## Modelando os dados

# Separa o df concatenado , usando a coluna is_train criada anteriormente apenas para isso
df_test = combine.loc[combine['is_train'] == 0]
df_train = combine.loc[combine['is_train'] == 1]

print(df_train.info())
print(df_test.info())

display(df_train.head())
display(df_test.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1482535 entries, 0 to 1482534
# Data columns (total 10 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   id                 1482535 non-null  int64
#  1   name               1482535 non-null  int32
#  2   item_condition_id  1482535 non-null  int64
#  3   brand_name         1482535 non-null  int16
#  4   shipping           1482535 non-null  int64
#  5   item_description   1482535 non-null  int32
#  6   main_cat           1482535 non-null  int8
#  7   sub_cat_1          1482535 non-null  int8
#  8   sub_cat_2          1482535 non-null  int16
#  9   is_train           1482535 non-null  int64
# dtypes: int16(2), int32(2), int64(4), int8(2)
# memory usage: 76.3 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 693359 entries, 0 to 693358
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 693359 non-null  int64
#  1   name               693359 non-null  int32
#  2   item_condition_id  693359 non-null  int64
#  3   brand_name         693359 non-null  int16
#  4   shipping           693359 non-null  int64
#  5   item_description   693359 non-null  int32
#  6   main_cat           693359 non-null  int8
#  7   sub_cat_1          693359 non-null  int8
#  8   sub_cat_2          693359 non-null  int16
#  9   is_train           693359 non-null  int64
# dtypes: int16(2), int32(2), int64(4), int8(2)
# memory usage: 35.7 MB
# None
#    id     name  item_condition_id  brand_name  shipping  item_description  \
# 0   0   916335                  3         646         1           1172054
# 1   1  1292428                  3        3889         0           1585540
# 2   2   131013                  1        4588         1            167133
# 3   3   802671                  1         646         1           1136644
# 4   4    65051                  1         646         0            531910
#
#    main_cat  sub_cat_1  sub_cat_2  is_train
# 0         6        103        774         1
# 1         2         31        216         1
# 2        10        104         98         1
# 3         4         56        411         1
# 4        10         59        543         1
#    id    name  item_condition_id  brand_name  shipping  item_description  \
# 0   0  323913                  1         646         1           1395408
# 1   1   65692                  1         646         1             95839
# 2   2  410310                  1        1094         1            383740
# 3   3  544668                  2         646         0             34209
# 4   4  810652                  3         646         1           1316301
#
#    main_cat  sub_cat_1  sub_cat_2  is_train
# 0        10         59        667         0
# 1         7         72        701         0
# 2         9          7        383         0
# 3        10         97        167         0
# 4         7         15        662         0

# %% [markdown]
# ## Montagem do treino e teste

# %%
#separando o X e o Y
x = df_train
y = train['price']

#Como estamos lidando com valores monetários desta vez, usaremos uma função log para transformação não linear p127
y = y.apply(lambda x: np.log(x) if x>0 else x)


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state=42)

# %% [markdown]
# ## Montagem do regressor

# %%
#impport de biblioteca 
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, accuracy_score


#Criando e aprendendo modelos
model = RandomForestRegressor(n_jobs=-1,random_state = 42 ,min_samples_leaf=2, n_estimators=250)
model.fit(x_train, y_train)


#Exibição de metricas

print(f'RMSE do traino : {model.score(x_train, y_train):.3f}')
y_pred = model.predict(x_test)
print(f'R²: {r2_score(y_test, y_pred):.3f}')
print(f'MAE: {mean_absolute_error(y_test, y_pred):.3f}')
print(f'RMSE: {mean_squared_error(y_test, y_pred):.3f}')
# Out:
# RMSE do traino : 0.872
# R²: 0.489
# MAE: 0.422
# RMSE: 0.322

# %%
#impport de biblioteca 
from sklearn.linear_model import LinearRegression

#Criando e aprendendo modelos
lr = LinearRegression()
lr.fit(x_train, y_train)
y_pred = lr.predict(x_test)


#Exibição de metricas
print(f'RMSE do treino : {lr.score(x_train, y_train):.3f}')
print(f'Valor R² do teste: {r2_score(y_test, y_pred):.3f}')
print(f'Valor MAE do teste: {mean_absolute_error(y_test, y_pred):.3f}')
print(f'RMSE do teste: {mean_squared_error(y_test, y_pred):.3f}')
# Out:
# RMSE do treino : 0.089
# Valor R² do teste: 0.087
# Valor MAE do teste: 0.589
# RMSE do teste: 0.575

# %%
#impport de biblioteca 
from sklearn.datasets import load_diabetes
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import VotingRegressor


#Criando e aprendendo modelos
reg1 = GradientBoostingRegressor(random_state=1)
reg2 = model
reg3 = LinearRegression()
ereg = VotingRegressor(estimators=[('gb', reg1), ('rf', reg2), ('lr', reg3)])
ereg = ereg.fit(x_train, y_train)

# %%
y_pred = ereg.predict(x_test)

#Exibição de metricas
print(f'RMSE do treino : {ereg.score(x_train, y_train):.3f}')
print(f'Valor R² do teste: {r2_score(y_test, y_pred):.3f}')
print(f'Valor MAE do teste: {mean_absolute_error(y_test, y_pred):.3f}')
print(f'RMSE do teste: {mean_squared_error(y_test, y_pred):.3f}')
# Out:
# RMSE do treino : 0.523
# Valor R² do teste: 0.368
# Valor MAE do teste: 0.486
# RMSE do teste: 0.398

# %% [markdown]
# Analisando os modelos verifiquei que o Linear Regression apresentou uma performance melhor que a do Random Forest Regressor, com isso vi a possibilidade do uso do Voting Regressor.
#
# O Voting Regressor vai utilizar 3 regressores (Gradient Boosting Regressor, Random Forest Regressor e o Linear Regression), retornar os valores médios previstos.
# Mas acabei obtendo um resultado pior do que utilizar apenas o Linear Regression.
#
# Com esses dados, pude verificar que a melhor escolha de regressor é o Linear Regression.
